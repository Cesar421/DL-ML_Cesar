# %% [markdown]
# # 📊 Model Exploration Notebook
#
# This notebook provides comprehensive analysis of three CIFAR-10 classification models:
# - **NullModel**: Tiny LeNet-like CNN (baseline)
# - **EfficientNet-B0**: Pre-trained CNN with transfer learning
# - **Hybrid**: ResNet18 + Vision Transformer
#
# ## Goals:
# 1. Analyze parameter counts and layer sizes
# 2. Measure computational complexity (FLOPs)
# 3. Estimate GPU memory usage
# 4. Compare model architectures
# 5. Answer assignment questions

# %%
# Cell 1: Setup and Basic Imports
import sys
import os

# Set environment variable to avoid OpenMP conflicts
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# Add project to path
sys.path.append('c:/Users/verwalter/Desktop/dlcv25-assignment-3-Cesar421')

import torch
import torch.nn as nn

print("✅ Basic imports successful!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Python executable: {sys.executable}")

# Import torchinfo separately to check
try:
    from torchinfo import summary
    print("✅ torchinfo imported")
except ImportError:
    print("❌ torchinfo not found. Install with: pip install torchinfo")

# Import timm
try:
    import timm
    print(f"✅ timm imported (version: {timm.__version__})")
except ImportError:
    print("❌ timm not found. Install with: pip install timm")

# Import vit-pytorch
try:
    from vit_pytorch import SimpleViT
    print("✅ vit-pytorch imported")
except ImportError:
    print("❌ vit-pytorch not found. Install with: pip install vit-pytorch")
# Out:
# ✅ Basic imports successful!
# PyTorch version: 2.9.1+cpu
# CUDA available: False
# Python executable: c:\Users\verwalter\anaconda3\python.exe
# ✅ torchinfo imported
# ✅ timm imported (version: 1.0.22)
# ✅ vit-pytorch imported

# %%
# Cell 1b: Import Project Models
# Run this cell after Cell 1 succeeds

try:
    from dlcv3.model import (
        build_null_model, 
        build_cnn_model, 
        build_cnn_transformer_hybrid_model
    )
    print("✅ Successfully imported your custom models!")
    print("   - build_null_model")
    print("   - build_cnn_model") 
    print("   - build_cnn_transformer_hybrid_model")
except ImportError as e:
    print(f"❌ Failed to import models: {e}")
    print("\nTroubleshooting:")
    print("1. Make sure you're in the dlcv_env conda environment")
    print("2. Check if dlcv3/model.py exists in your project")
    print("3. Try running: pip install -e .")
# Out:
# ✅ Successfully imported your custom models!
#    - build_null_model
#    - build_cnn_model
#    - build_cnn_transformer_hybrid_model

# %%
# Cell 2: Define Model Summary Function

def summarize_model(model, batch_size=128, gpu_memory_gb=16):
    """
    Print detailed model summary using torchinfo.
    Answers all assignment questions about parameters, FLOPs, and memory.
    
    Args:
        model: PyTorch model to analyze
        batch_size: Input batch size for analysis
        gpu_memory_gb: Available GPU memory for max batch size calculation
    """
    input_shape = (batch_size, 3, 32, 32)

    print("\n" + "="*100)
    print(f"MODEL SUMMARY FOR BATCH SIZE {batch_size}")
    print("="*100 + "\n")

    # Generate comprehensive summary with all required metrics
    model_stats = summary(
        model,
        input_size=input_shape,
        col_names=[
            "input_size",
            "output_size",
            "num_params",
            "params_percent",
            "kernel_size",
            "mult_adds",
            "trainable",
        ],
        col_width=20,
        row_settings=["var_names"],
        depth=5,
        device="cpu",
        verbose=1,
    )

    print("\n" + "="*100)
    print("📊 KEY STATISTICS - ANSWERS TO ASSIGNMENT QUESTIONS")
    print("="*100)

    # Question 1: How many parameters do they have?
    total_params = model_stats.total_params
    trainable_params = model_stats.trainable_params
    non_trainable_params = total_params - trainable_params
    
    print(f"\n1️⃣  PARAMETER COUNT:")
    print(f"    ├─ Total Parameters:        {total_params:,}")
    print(f"    ├─ Trainable Parameters:    {trainable_params:,}")
    print(f"    └─ Non-trainable Parameters: {non_trainable_params:,}")

    # Question 2: Which layers have the most parameters?
    print(f"\n2️⃣  LARGEST LAYERS:")
    print(f"    └─ See 'num_params' and 'params_percent' columns in the table above")
    print(f"       (Layers sorted by parameter count are visible in the summary)")

    # Question 3: How many floating-point operations?
    total_mult_adds = model_stats.total_mult_adds
    total_flops_gflops = total_mult_adds / 1e9  # Convert to GFLOPs
    
    print(f"\n3️⃣  FLOATING-POINT OPERATIONS (FLOPs):")
    print(f"    ├─ Total Multiply-Adds:     {total_mult_adds:,}")
    print(f"    └─ Approximate GFLOPs:      {total_flops_gflops:.4f}")

    # Question 4: Memory usage on GPU
    param_memory_mb = (total_params * 4) / (1024 ** 2)  # 4 bytes per float32
    
    # Rough estimation of activation memory
    estimated_activation_mb = param_memory_mb * 5  # Conservative estimate
    
    # Total memory = params + activations + gradients + optimizer state
    gradient_memory_mb = param_memory_mb
    optimizer_memory_mb = param_memory_mb * 2  # Adam optimizer
    
    total_training_memory_mb = (
        param_memory_mb + 
        estimated_activation_mb + 
        gradient_memory_mb + 
        optimizer_memory_mb
    )
    
    print(f"\n4️⃣  GPU MEMORY USAGE (for batch size {batch_size}):")
    print(f"    ├─ Model Parameters:        {param_memory_mb:.2f} MB")
    print(f"    ├─ Activations (estimated): {estimated_activation_mb:.2f} MB")
    print(f"    ├─ Gradients:               {gradient_memory_mb:.2f} MB")
    print(f"    ├─ Optimizer State (Adam):  {optimizer_memory_mb:.2f} MB")
    print(f"    └─ TOTAL (estimated):       {total_training_memory_mb:.2f} MB")

    # Question 5: How many items could fit in GPU?
    gpu_memory_mb = gpu_memory_gb * 1024
    
    # Memory per sample = total_memory / batch_size
    memory_per_sample_mb = total_training_memory_mb / batch_size
    
    # Max batch size = GPU memory / memory per sample
    max_batch_size_theoretical = int(gpu_memory_mb / memory_per_sample_mb)
    
    # Apply safety factor (typically use 70-80% of GPU memory)
    max_batch_size_safe = int(max_batch_size_theoretical * 0.75)
    
    print(f"\n5️⃣  MAXIMUM BATCH SIZE (assuming {gpu_memory_gb}GB GPU):")
    print(f"    ├─ Memory per sample:       {memory_per_sample_mb:.2f} MB")
    print(f"    ├─ Theoretical max:         {max_batch_size_theoretical}")
    print(f"    └─ Safe max (75% GPU):      {max_batch_size_safe}")
    
    print("\n" + "="*100 + "\n")

    return model_stats

print("✅ summarize_model function defined!")
# Out:
# ✅ summarize_model function defined!

# %% [markdown]
# ## 🔍 Model 1: NullModel (Tiny LeNet-like CNN)
#
# Simple baseline CNN with 2 convolutional blocks and 2 fully-connected layers.

# %%
# Cell 3: Analyze NullModel

print("🔍 ANALYZING NULLMODEL (Tiny LeNet-like CNN)\n")

# Build model
null_model = build_null_model()

# Summarize with batch size 128
null_stats = summarize_model(null_model, batch_size=128)

# Show architecture
print("\n📌 NullModel Architecture:")
print(null_model)
# Out:
# 🔍 ANALYZING NULLMODEL (Tiny LeNet-like CNN)
#
#
# ====================================================================================================
# MODEL SUMMARY FOR BATCH SIZE 128
# ====================================================================================================
#
# ====================================================================================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Param %              Kernel Shape         Mult-Adds            Trainable
# ====================================================================================================================================================================================
# NullModel (NullModel)                    [128, 3, 32, 32]     [128, 10]            --                        --              --                   --                   True
# ├─Sequential (block1)                    [128, 3, 32, 32]     [128, 32, 16, 16]    --                        --              --                   --                   True
# │    └─Conv2d (0)                        [128, 3, 32, 32]     [128, 32, 32, 32]    896                    0.16%              [3, 3]               117,440,512          True
# │    └─ReLU (1)                          [128, 32, 32, 32]    [128, 32, 32, 32]    --                        --              --                   --                   --
# │    └─MaxPool2d (2)                     [128, 32, 32, 32]    [128, 32, 16, 16]    --                        --              2                    --                   --
# ├─Sequential (block2)                    [128, 32, 16, 16]    [128, 64, 8, 8]      --                        --              --                   --                   True
# │    └─Conv2d (0)                        [128, 32, 16, 16]    [128, 64, 16, 16]    18,496                 3.39%              [3, 3]               606,076,928          True
# │    └─ReLU (1)                          [128, 64, 16, 16]    [128, 64, 16, 16]    --                        --              --                   --                   --
# │    └─MaxPool2d (2)                     [128, 64, 16, 16]    [128, 64, 8, 8]      --                        --              2                    --                   --
# ├─Sequential (head)                      [128, 64, 8, 8]      [128, 10]            --                        --              --                   --                   True
# │    └─Flatten (0)                       [128, 64, 8, 8]      [128, 4096]          --                        --              --                   --                   --
# │    └─Linear (1)                        [128, 4096]          [128, 128]           524,416               96.21%              --                   67,125,248           True
# │    └─ReLU (2)                          [128, 128]           [128, 128]           --                        --              --                   --                   --
# │    └─Linear (3)                        [128, 128]           [128, 10]            1,290                  0.24%              --                   165,120              True
# ====================================================================================================================================================================================
# Total params: 545,098
# Trainable params: 545,098
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 790.81
# ====================================================================================================================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 50.47
# Params size (MB): 2.18
# Estimated Total Size (MB): 54.23
# ====================================================================================================================================================================================
#
# ====================================================================================================
# 📊 KEY STATISTICS - ANSWERS TO ASSIGNMENT QUESTIONS
# ====================================================================================================
#
# 1️⃣  PARAMETER COUNT:
#     ├─ Total Parameters:        545,098
#     ├─ Trainable Parameters:    545,098
#     └─ Non-trainable Parameters: 0
#
# 2️⃣  LARGEST LAYERS:
#     └─ See 'num_params' and 'params_percent' columns in the table above
#        (Layers sorted by parameter count are visible in the summary)
#
# 3️⃣  FLOATING-POINT OPERATIONS (FLOPs):
#     ├─ Total Multiply-Adds:     790,807,808
#     └─ Approximate GFLOPs:      0.7908
#
# 4️⃣  GPU MEMORY USAGE (for batch size 128):
#     ├─ Model Parameters:        2.08 MB
#     ├─ Activations (estimated): 10.40 MB
#     ├─ Gradients:               2.08 MB
#     ├─ Optimizer State (Adam):  4.16 MB
#     └─ TOTAL (estimated):       18.71 MB
#
# 5️⃣  MAXIMUM BATCH SIZE (assuming 16GB GPU):
#     ├─ Memory per sample:       0.15 MB
#     ├─ Theoretical max:         112060
#     └─ Safe max (75% GPU):      84045
#
# ====================================================================================================
#
#
# 📌 NullModel Architecture:
# NullModel(
#   (block1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (head): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=4096, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## 🔍 Model 2: EfficientNet-B0 (Pre-trained CNN)
#
# State-of-the-art CNN with compound scaling and transfer learning from ImageNet.

# %%
# Cell 4: Analyze EfficientNet-B0

print("🔍 ANALYZING EFFICIENTNET-B0 (Pre-trained CNN)\n")

# Build model
efficientnet_model = build_cnn_model()

# Summarize with batch size 128
efficientnet_stats = summarize_model(efficientnet_model, batch_size=128)
# Out:
# 🔍 ANALYZING EFFICIENTNET-B0 (Pre-trained CNN)
#
#
# ====================================================================================================
# MODEL SUMMARY FOR BATCH SIZE 128
# ====================================================================================================
#
#
# ====================================================================================================
# MODEL SUMMARY FOR BATCH SIZE 128
# ====================================================================================================
#
# ==============================================================================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Param %              Kernel Shape         Mult-Adds            Trainable
# ==============================================================================================================================================================================================
# EfficientNet (EfficientNet)                        [128, 3, 32, 32]     [128, 10]            --                        --              --                   --                   True
# ├─Conv2d (conv_stem)                               [128, 3, 32, 32]     [128, 32, 16, 16]    864                    0.02%              [3, 3]               28,311,552           True
# ├─BatchNormAct2d (bn1)                             [128, 32, 16, 16]    [128, 32, 16, 16]    64                     0.00%              --                   --                   True
# │    └─Identity (drop)                             [128, 32, 16, 16]    [128, 32, 16, 16]    --                        --              --                   --                   --
# │    └─SiLU (act)                                  [128, 32, 16, 16]    [128, 32, 16, 16]    --                        --              --                   --                   --
# ├─Sequential (blocks)                              [128, 32, 16, 16]    [128, 320, 1, 1]     --                        --              --                   --                   True
# │    └─Sequential (0)                              [128, 32, 16, 16]    [128, 16, 16, 16]    --                        --              --                   --                   True
# │    │    └─DepthwiseSeparableConv (0)             [128, 32, 16, 16]    [128, 16, 16, 16]    --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_dw)                  [128, 32, 16, 16]    [128, 32, 16, 16]    288                    0.01%              [3, 3]               9,437,184            True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 32, 16, 16]    [128, 32, 16, 16]    64                     0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 32, 16, 16]    [128, 32, 16, 16]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 32, 16, 16]    [128, 32, 16, 16]    --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 32, 16, 16]    [128, 32, 16, 16]    --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 32, 16, 16]    [128, 32, 16, 16]    --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 32, 1, 1]      [128, 8, 1, 1]       264                    0.01%              [1, 1]               33,792               True
# │    │    │    │    └─SiLU (act1)                  [128, 8, 1, 1]       [128, 8, 1, 1]       --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 8, 1, 1]       [128, 32, 1, 1]      288                    0.01%              [1, 1]               36,864               True
# │    │    │    │    └─Sigmoid (gate)               [128, 32, 1, 1]      [128, 32, 1, 1]      --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pw)                  [128, 32, 16, 16]    [128, 16, 16, 16]    512                    0.01%              [1, 1]               16,777,216           True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 16, 16, 16]    [128, 16, 16, 16]    32                     0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 16, 16, 16]    [128, 16, 16, 16]    --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 16, 16, 16]    [128, 16, 16, 16]    --                        --              --                   --                   --
# │    └─Sequential (1)                              [128, 16, 16, 16]    [128, 24, 8, 8]      --                        --              --                   --                   True
# │    │    └─InvertedResidual (0)                   [128, 16, 16, 16]    [128, 24, 8, 8]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 16, 16, 16]    [128, 96, 16, 16]    1,536                  0.04%              [1, 1]               50,331,648           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 96, 16, 16]    [128, 96, 16, 16]    192                    0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 96, 16, 16]    [128, 96, 16, 16]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 96, 16, 16]    [128, 96, 16, 16]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 96, 16, 16]    [128, 96, 8, 8]      864                    0.02%              [3, 3]               7,077,888            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 96, 8, 8]      [128, 96, 8, 8]      192                    0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 96, 8, 8]      [128, 96, 8, 8]      --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 96, 8, 8]      [128, 96, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 96, 8, 8]      [128, 96, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 96, 8, 8]      [128, 96, 8, 8]      --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 96, 1, 1]      [128, 4, 1, 1]       388                    0.01%              [1, 1]               49,664               True
# │    │    │    │    └─SiLU (act1)                  [128, 4, 1, 1]       [128, 4, 1, 1]       --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 4, 1, 1]       [128, 96, 1, 1]      480                    0.01%              [1, 1]               61,440               True
# │    │    │    │    └─Sigmoid (gate)               [128, 96, 1, 1]      [128, 96, 1, 1]      --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 96, 8, 8]      [128, 24, 8, 8]      2,304                  0.06%              [1, 1]               18,874,368           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 24, 8, 8]      [128, 24, 8, 8]      48                     0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 24, 8, 8]      [128, 24, 8, 8]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 24, 8, 8]      [128, 24, 8, 8]      --                        --              --                   --                   --
# │    │    └─InvertedResidual (1)                   [128, 24, 8, 8]      [128, 24, 8, 8]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 24, 8, 8]      [128, 144, 8, 8]     3,456                  0.09%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 144, 8, 8]     [128, 144, 8, 8]     288                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 144, 8, 8]     [128, 144, 8, 8]     1,296                  0.03%              [3, 3]               10,616,832           True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 144, 8, 8]     [128, 144, 8, 8]     288                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 144, 1, 1]     [128, 6, 1, 1]       870                    0.02%              [1, 1]               111,360              True
# │    │    │    │    └─SiLU (act1)                  [128, 6, 1, 1]       [128, 6, 1, 1]       --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 6, 1, 1]       [128, 144, 1, 1]     1,008                  0.03%              [1, 1]               129,024              True
# │    │    │    │    └─Sigmoid (gate)               [128, 144, 1, 1]     [128, 144, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 144, 8, 8]     [128, 24, 8, 8]      3,456                  0.09%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 24, 8, 8]      [128, 24, 8, 8]      48                     0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 24, 8, 8]      [128, 24, 8, 8]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 24, 8, 8]      [128, 24, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 24, 8, 8]      [128, 24, 8, 8]      --                        --              --                   --                   --
# │    └─Sequential (2)                              [128, 24, 8, 8]      [128, 40, 4, 4]      --                        --              --                   --                   True
# │    │    └─InvertedResidual (0)                   [128, 24, 8, 8]      [128, 40, 4, 4]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 24, 8, 8]      [128, 144, 8, 8]     3,456                  0.09%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 144, 8, 8]     [128, 144, 8, 8]     288                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 144, 8, 8]     [128, 144, 8, 8]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 144, 8, 8]     [128, 144, 4, 4]     3,600                  0.09%              [5, 5]               7,372,800            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 144, 4, 4]     [128, 144, 4, 4]     288                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 144, 4, 4]     [128, 144, 4, 4]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 144, 4, 4]     [128, 144, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 144, 4, 4]     [128, 144, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 144, 4, 4]     [128, 144, 4, 4]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 144, 1, 1]     [128, 6, 1, 1]       870                    0.02%              [1, 1]               111,360              True
# │    │    │    │    └─SiLU (act1)                  [128, 6, 1, 1]       [128, 6, 1, 1]       --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 6, 1, 1]       [128, 144, 1, 1]     1,008                  0.03%              [1, 1]               129,024              True
# │    │    │    │    └─Sigmoid (gate)               [128, 144, 1, 1]     [128, 144, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 144, 4, 4]     [128, 40, 4, 4]      5,760                  0.14%              [1, 1]               11,796,480           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 40, 4, 4]      [128, 40, 4, 4]      80                     0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 40, 4, 4]      [128, 40, 4, 4]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 40, 4, 4]      [128, 40, 4, 4]      --                        --              --                   --                   --
# │    │    └─InvertedResidual (1)                   [128, 40, 4, 4]      [128, 40, 4, 4]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 40, 4, 4]      [128, 240, 4, 4]     9,600                  0.24%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 240, 4, 4]     [128, 240, 4, 4]     480                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 240, 4, 4]     [128, 240, 4, 4]     6,000                  0.15%              [5, 5]               12,288,000           True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 240, 4, 4]     [128, 240, 4, 4]     480                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 240, 1, 1]     [128, 10, 1, 1]      2,410                  0.06%              [1, 1]               308,480              True
# │    │    │    │    └─SiLU (act1)                  [128, 10, 1, 1]      [128, 10, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 10, 1, 1]      [128, 240, 1, 1]     2,640                  0.07%              [1, 1]               337,920              True
# │    │    │    │    └─Sigmoid (gate)               [128, 240, 1, 1]     [128, 240, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 240, 4, 4]     [128, 40, 4, 4]      9,600                  0.24%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 40, 4, 4]      [128, 40, 4, 4]      80                     0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 40, 4, 4]      [128, 40, 4, 4]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 40, 4, 4]      [128, 40, 4, 4]      --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 40, 4, 4]      [128, 40, 4, 4]      --                        --              --                   --                   --
# │    └─Sequential (3)                              [128, 40, 4, 4]      [128, 80, 2, 2]      --                        --              --                   --                   True
# │    │    └─InvertedResidual (0)                   [128, 40, 4, 4]      [128, 80, 2, 2]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 40, 4, 4]      [128, 240, 4, 4]     9,600                  0.24%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 240, 4, 4]     [128, 240, 4, 4]     480                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 240, 4, 4]     [128, 240, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 240, 4, 4]     [128, 240, 2, 2]     2,160                  0.05%              [3, 3]               1,105,920            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 240, 2, 2]     [128, 240, 2, 2]     480                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 240, 2, 2]     [128, 240, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 240, 2, 2]     [128, 240, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 240, 2, 2]     [128, 240, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 240, 2, 2]     [128, 240, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 240, 1, 1]     [128, 10, 1, 1]      2,410                  0.06%              [1, 1]               308,480              True
# │    │    │    │    └─SiLU (act1)                  [128, 10, 1, 1]      [128, 10, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 10, 1, 1]      [128, 240, 1, 1]     2,640                  0.07%              [1, 1]               337,920              True
# │    │    │    │    └─Sigmoid (gate)               [128, 240, 1, 1]     [128, 240, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 240, 2, 2]     [128, 80, 2, 2]      19,200                 0.48%              [1, 1]               9,830,400            True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 80, 2, 2]      [128, 80, 2, 2]      160                    0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    └─InvertedResidual (1)                   [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 80, 2, 2]      [128, 480, 2, 2]     38,400                 0.96%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 480, 2, 2]     [128, 480, 2, 2]     960                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 480, 2, 2]     [128, 480, 2, 2]     4,320                  0.11%              [3, 3]               2,211,840            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 480, 2, 2]     [128, 480, 2, 2]     960                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 480, 1, 1]     [128, 20, 1, 1]      9,620                  0.24%              [1, 1]               1,231,360            True
# │    │    │    │    └─SiLU (act1)                  [128, 20, 1, 1]      [128, 20, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 20, 1, 1]      [128, 480, 1, 1]     10,080                 0.25%              [1, 1]               1,290,240            True
# │    │    │    │    └─Sigmoid (gate)               [128, 480, 1, 1]     [128, 480, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 480, 2, 2]     [128, 80, 2, 2]      38,400                 0.96%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 80, 2, 2]      [128, 80, 2, 2]      160                    0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    └─InvertedResidual (2)                   [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 80, 2, 2]      [128, 480, 2, 2]     38,400                 0.96%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 480, 2, 2]     [128, 480, 2, 2]     960                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 480, 2, 2]     [128, 480, 2, 2]     4,320                  0.11%              [3, 3]               2,211,840            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 480, 2, 2]     [128, 480, 2, 2]     960                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 480, 1, 1]     [128, 20, 1, 1]      9,620                  0.24%              [1, 1]               1,231,360            True
# │    │    │    │    └─SiLU (act1)                  [128, 20, 1, 1]      [128, 20, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 20, 1, 1]      [128, 480, 1, 1]     10,080                 0.25%              [1, 1]               1,290,240            True
# │    │    │    │    └─Sigmoid (gate)               [128, 480, 1, 1]     [128, 480, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 480, 2, 2]     [128, 80, 2, 2]      38,400                 0.96%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 80, 2, 2]      [128, 80, 2, 2]      160                    0.00%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 80, 2, 2]      [128, 80, 2, 2]      --                        --              --                   --                   --
# │    └─Sequential (4)                              [128, 80, 2, 2]      [128, 112, 2, 2]     --                        --              --                   --                   True
# │    │    └─InvertedResidual (0)                   [128, 80, 2, 2]      [128, 112, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 80, 2, 2]      [128, 480, 2, 2]     38,400                 0.96%              [1, 1]               19,660,800           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 480, 2, 2]     [128, 480, 2, 2]     960                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 480, 2, 2]     [128, 480, 2, 2]     12,000                 0.30%              [5, 5]               6,144,000            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 480, 2, 2]     [128, 480, 2, 2]     960                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 480, 2, 2]     [128, 480, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 480, 1, 1]     [128, 20, 1, 1]      9,620                  0.24%              [1, 1]               1,231,360            True
# │    │    │    │    └─SiLU (act1)                  [128, 20, 1, 1]      [128, 20, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 20, 1, 1]      [128, 480, 1, 1]     10,080                 0.25%              [1, 1]               1,290,240            True
# │    │    │    │    └─Sigmoid (gate)               [128, 480, 1, 1]     [128, 480, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 480, 2, 2]     [128, 112, 2, 2]     53,760                 1.34%              [1, 1]               27,525,120           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 112, 2, 2]     [128, 112, 2, 2]     224                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    └─InvertedResidual (1)                   [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 112, 2, 2]     [128, 672, 2, 2]     75,264                 1.87%              [1, 1]               38,535,168           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 672, 2, 2]     [128, 672, 2, 2]     1,344                  0.03%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 672, 2, 2]     [128, 672, 2, 2]     16,800                 0.42%              [5, 5]               8,601,600            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 672, 2, 2]     [128, 672, 2, 2]     1,344                  0.03%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 672, 1, 1]     [128, 28, 1, 1]      18,844                 0.47%              [1, 1]               2,412,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 28, 1, 1]      [128, 28, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 28, 1, 1]      [128, 672, 1, 1]     19,488                 0.48%              [1, 1]               2,494,464            True
# │    │    │    │    └─Sigmoid (gate)               [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 672, 2, 2]     [128, 112, 2, 2]     75,264                 1.87%              [1, 1]               38,535,168           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 112, 2, 2]     [128, 112, 2, 2]     224                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    └─InvertedResidual (2)                   [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 112, 2, 2]     [128, 672, 2, 2]     75,264                 1.87%              [1, 1]               38,535,168           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 672, 2, 2]     [128, 672, 2, 2]     1,344                  0.03%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 672, 2, 2]     [128, 672, 2, 2]     16,800                 0.42%              [5, 5]               8,601,600            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 672, 2, 2]     [128, 672, 2, 2]     1,344                  0.03%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 672, 1, 1]     [128, 28, 1, 1]      18,844                 0.47%              [1, 1]               2,412,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 28, 1, 1]      [128, 28, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 28, 1, 1]      [128, 672, 1, 1]     19,488                 0.48%              [1, 1]               2,494,464            True
# │    │    │    │    └─Sigmoid (gate)               [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 672, 2, 2]     [128, 112, 2, 2]     75,264                 1.87%              [1, 1]               38,535,168           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 112, 2, 2]     [128, 112, 2, 2]     224                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 112, 2, 2]     [128, 112, 2, 2]     --                        --              --                   --                   --
# │    └─Sequential (5)                              [128, 112, 2, 2]     [128, 192, 1, 1]     --                        --              --                   --                   True
# │    │    └─InvertedResidual (0)                   [128, 112, 2, 2]     [128, 192, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 112, 2, 2]     [128, 672, 2, 2]     75,264                 1.87%              [1, 1]               38,535,168           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 672, 2, 2]     [128, 672, 2, 2]     1,344                  0.03%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 672, 2, 2]     [128, 672, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 672, 2, 2]     [128, 672, 1, 1]     16,800                 0.42%              [5, 5]               2,150,400            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 672, 1, 1]     [128, 672, 1, 1]     1,344                  0.03%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 672, 1, 1]     [128, 28, 1, 1]      18,844                 0.47%              [1, 1]               2,412,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 28, 1, 1]      [128, 28, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 28, 1, 1]      [128, 672, 1, 1]     19,488                 0.48%              [1, 1]               2,494,464            True
# │    │    │    │    └─Sigmoid (gate)               [128, 672, 1, 1]     [128, 672, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 672, 1, 1]     [128, 192, 1, 1]     129,024                3.21%              [1, 1]               16,515,072           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 192, 1, 1]     [128, 192, 1, 1]     384                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    └─InvertedResidual (1)                   [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 192, 1, 1]     [128, 1152, 1, 1]    221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 1152, 1, 1]    [128, 1152, 1, 1]    28,800                 0.72%              [5, 5]               3,686,400            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 1152, 1, 1]    [128, 48, 1, 1]      55,344                 1.38%              [1, 1]               7,084,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 48, 1, 1]      [128, 48, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 48, 1, 1]      [128, 1152, 1, 1]    56,448                 1.40%              [1, 1]               7,225,344            True
# │    │    │    │    └─Sigmoid (gate)               [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 1152, 1, 1]    [128, 192, 1, 1]     221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 192, 1, 1]     [128, 192, 1, 1]     384                    0.01%              --                   --                   True
# ...
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 1152, 1, 1]    [128, 48, 1, 1]      55,344                 1.38%              [1, 1]               7,084,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 48, 1, 1]      [128, 48, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 48, 1, 1]      [128, 1152, 1, 1]    56,448                 1.40%              [1, 1]               7,225,344            True
# │    │    │    │    └─Sigmoid (gate)               [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 1152, 1, 1]    [128, 192, 1, 1]     221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 192, 1, 1]     [128, 192, 1, 1]     384                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    └─InvertedResidual (2)                   [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 192, 1, 1]     [128, 1152, 1, 1]    221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 1152, 1, 1]    [128, 1152, 1, 1]    28,800                 0.72%              [5, 5]               3,686,400            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 1152, 1, 1]    [128, 48, 1, 1]      55,344                 1.38%              [1, 1]               7,084,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 48, 1, 1]      [128, 48, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 48, 1, 1]      [128, 1152, 1, 1]    56,448                 1.40%              [1, 1]               7,225,344            True
# │    │    │    │    └─Sigmoid (gate)               [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 1152, 1, 1]    [128, 192, 1, 1]     221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 192, 1, 1]     [128, 192, 1, 1]     384                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    └─InvertedResidual (3)                   [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 192, 1, 1]     [128, 1152, 1, 1]    221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 1152, 1, 1]    [128, 1152, 1, 1]    28,800                 0.72%              [5, 5]               3,686,400            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 1152, 1, 1]    [128, 48, 1, 1]      55,344                 1.38%              [1, 1]               7,084,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 48, 1, 1]      [128, 48, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 48, 1, 1]      [128, 1152, 1, 1]    56,448                 1.40%              [1, 1]               7,225,344            True
# │    │    │    │    └─Sigmoid (gate)               [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 1152, 1, 1]    [128, 192, 1, 1]     221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 192, 1, 1]     [128, 192, 1, 1]     384                    0.01%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (drop_path)              [128, 192, 1, 1]     [128, 192, 1, 1]     --                        --              --                   --                   --
# │    └─Sequential (6)                              [128, 192, 1, 1]     [128, 320, 1, 1]     --                        --              --                   --                   True
# │    │    └─InvertedResidual (0)                   [128, 192, 1, 1]     [128, 320, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv_pw)                  [128, 192, 1, 1]     [128, 1152, 1, 1]    221,184                5.50%              [1, 1]               28,311,552           True
# │    │    │    └─BatchNormAct2d (bn1)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_dw)                  [128, 1152, 1, 1]    [128, 1152, 1, 1]    10,368                 0.26%              [3, 3]               1,327,104            True
# │    │    │    └─BatchNormAct2d (bn2)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    2,304                  0.06%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    │    └─SiLU (act)                   [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─SqueezeExcite (se)                [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (conv_reduce)         [128, 1152, 1, 1]    [128, 48, 1, 1]      55,344                 1.38%              [1, 1]               7,084,032            True
# │    │    │    │    └─SiLU (act1)                  [128, 48, 1, 1]      [128, 48, 1, 1]      --                        --              --                   --                   --
# │    │    │    │    └─Conv2d (conv_expand)         [128, 48, 1, 1]      [128, 1152, 1, 1]    56,448                 1.40%              [1, 1]               7,225,344            True
# │    │    │    │    └─Sigmoid (gate)               [128, 1152, 1, 1]    [128, 1152, 1, 1]    --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv_pwl)                 [128, 1152, 1, 1]    [128, 320, 1, 1]     368,640                9.17%              [1, 1]               47,185,920           True
# │    │    │    └─BatchNormAct2d (bn3)              [128, 320, 1, 1]     [128, 320, 1, 1]     640                    0.02%              --                   --                   True
# │    │    │    │    └─Identity (drop)              [128, 320, 1, 1]     [128, 320, 1, 1]     --                        --              --                   --                   --
# │    │    │    │    └─Identity (act)               [128, 320, 1, 1]     [128, 320, 1, 1]     --                        --              --                   --                   --
# ├─Conv2d (conv_head)                               [128, 320, 1, 1]     [128, 1280, 1, 1]    409,600               10.19%              [1, 1]               52,428,800           True
# ├─BatchNormAct2d (bn2)                             [128, 1280, 1, 1]    [128, 1280, 1, 1]    2,560                  0.06%              --                   --                   True
# │    └─Identity (drop)                             [128, 1280, 1, 1]    [128, 1280, 1, 1]    --                        --              --                   --                   --
# │    └─SiLU (act)                                  [128, 1280, 1, 1]    [128, 1280, 1, 1]    --                        --              --                   --                   --
# ├─SelectAdaptivePool2d (global_pool)               [128, 1280, 1, 1]    [128, 1280]          --                        --              --                   --                   --
# │    └─AdaptiveAvgPool2d (pool)                    [128, 1280, 1, 1]    [128, 1280, 1, 1]    --                        --              --                   --                   --
# │    └─Flatten (flatten)                           [128, 1280, 1, 1]    [128, 1280]          --                        --              --                   --                   --
# ├─Linear (classifier)                              [128, 1280]          [128, 10]            12,810                 0.32%              --                   1,639,680            True
# ==============================================================================================================================================================================================
# Total params: 4,020,358
# Trainable params: 4,020,358
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.09
# ==============================================================================================================================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 150.38
# Params size (MB): 15.91
# Estimated Total Size (MB): 167.86
# ==============================================================================================================================================================================================
#
# ====================================================================================================
# 📊 KEY STATISTICS - ANSWERS TO ASSIGNMENT QUESTIONS
# ====================================================================================================
#
# 1️⃣  PARAMETER COUNT:
#     ├─ Total Parameters:        4,020,358
#     ├─ Trainable Parameters:    4,020,358
#     └─ Non-trainable Parameters: 0
#
# 2️⃣  LARGEST LAYERS:
#     └─ See 'num_params' and 'params_percent' columns in the table above
#        (Layers sorted by parameter count are visible in the summary)
#
# 3️⃣  FLOATING-POINT OPERATIONS (FLOPs):
#     ├─ Total Multiply-Adds:     1,085,977,344
#     └─ Approximate GFLOPs:      1.0860
#
# 4️⃣  GPU MEMORY USAGE (for batch size 128):
#     ├─ Model Parameters:        15.34 MB
#     ├─ Activations (estimated): 76.68 MB
#     ├─ Gradients:               15.34 MB
#     ├─ Optimizer State (Adam):  30.67 MB
#     └─ TOTAL (estimated):       138.03 MB
#
# 5️⃣  MAXIMUM BATCH SIZE (assuming 16GB GPU):
#     ├─ Memory per sample:       1.08 MB
#     ├─ Theoretical max:         15193
#     └─ Safe max (75% GPU):      11394
#
# ====================================================================================================

# %% [markdown]
# ## 🔍 Model 3: Hybrid (ResNet18 + Vision Transformer)
#
# Combines CNN feature extraction with Transformer's global attention mechanism.

# %%
# Cell 5: Analyze Hybrid Model

print("🔍 ANALYZING HYBRID MODEL (ResNet18 + SimpleViT)\n")

# Build model
hybrid_model = build_cnn_transformer_hybrid_model()

# Summarize with batch size 64 (smaller due to memory)
hybrid_stats = summarize_model(hybrid_model, batch_size=128)

# Show architecture components
print("\n📌 Hybrid Model Components:")
print(f"Backbone: {type(hybrid_model.backbone).__name__}")
print(f"Transformer: {type(hybrid_model.transformer).__name__}")
# Out:
# 🔍 ANALYZING HYBRID MODEL (ResNet18 + SimpleViT)
#
#
# ====================================================================================================
# MODEL SUMMARY FOR BATCH SIZE 128
# ====================================================================================================
#
#
# ====================================================================================================
# MODEL SUMMARY FOR BATCH SIZE 128
# ====================================================================================================
#
# ==============================================================================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Param %              Kernel Shape         Mult-Adds            Trainable
# ==============================================================================================================================================================================================
# HybridModel (HybridModel)                          [128, 3, 32, 32]     [128, 10]            --                        --              --                   --                   True
# ├─FeatureListNet (backbone)                        [128, 3, 32, 32]     [128, 64, 16, 16]    --                        --              --                   --                   True
# │    └─Conv2d (conv1)                              [128, 3, 32, 32]     [128, 64, 16, 16]    9,408                  0.07%              [7, 7]               308,281,344          True
# │    └─BatchNorm2d (bn1)                           [128, 64, 16, 16]    [128, 64, 16, 16]    128                    0.00%              --                   16,384               True
# │    └─ReLU (act1)                                 [128, 64, 16, 16]    [128, 64, 16, 16]    --                        --              --                   --                   --
# │    └─MaxPool2d (maxpool)                         [128, 64, 16, 16]    [128, 64, 8, 8]      --                        --              3                    --                   --
# │    └─Sequential (layer1)                         [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─Identity (drop_block)             [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─ReLU (act2)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─Identity (drop_block)             [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─ReLU (act2)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    └─Sequential (layer2)                         [128, 64, 8, 8]      [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 64, 8, 8]      [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 64, 8, 8]      [128, 128, 4, 4]     73,728                 0.55%              [3, 3]               150,994,944          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─Identity (drop_block)             [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 128, 4, 4]     [128, 128, 4, 4]     147,456                1.10%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─Sequential (downsample)           [128, 64, 8, 8]      [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (0)                   [128, 64, 8, 8]      [128, 128, 4, 4]     8,192                  0.06%              [1, 1]               16,777,216           True
# │    │    │    │    └─BatchNorm2d (1)              [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─ReLU (act2)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 128, 4, 4]     [128, 128, 4, 4]     147,456                1.10%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─Identity (drop_block)             [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 128, 4, 4]     [128, 128, 4, 4]     147,456                1.10%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─ReLU (act2)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    └─Sequential (layer3)                         [128, 128, 4, 4]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 128, 4, 4]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 128, 4, 4]     [128, 256, 2, 2]     294,912                2.21%              [3, 3]               150,994,944          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─Identity (drop_block)             [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 256, 2, 2]     [128, 256, 2, 2]     589,824                4.42%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─Sequential (downsample)           [128, 128, 4, 4]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (0)                   [128, 128, 4, 4]     [128, 256, 2, 2]     32,768                 0.25%              [1, 1]               16,777,216           True
# │    │    │    │    └─BatchNorm2d (1)              [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─ReLU (act2)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 256, 2, 2]     [128, 256, 2, 2]     589,824                4.42%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─Identity (drop_block)             [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 256, 2, 2]     [128, 256, 2, 2]     589,824                4.42%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─ReLU (act2)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    └─Sequential (layer4)                         [128, 256, 2, 2]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 256, 2, 2]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 256, 2, 2]     [128, 512, 1, 1]     1,179,648              8.84%              [3, 3]               150,994,944          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─Identity (drop_block)             [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 512, 1, 1]     [128, 512, 1, 1]     2,359,296             17.67%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─Sequential (downsample)           [128, 256, 2, 2]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (0)                   [128, 256, 2, 2]     [128, 512, 1, 1]     131,072                0.98%              [1, 1]               16,777,216           True
# │    │    │    │    └─BatchNorm2d (1)              [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─ReLU (act2)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 512, 1, 1]     [128, 512, 1, 1]     2,359,296             17.67%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─Identity (drop_block)             [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 512, 1, 1]     [128, 512, 1, 1]     2,359,296             17.67%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─ReLU (act2)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# ├─SimpleViT (transformer)                          [128, 64, 8, 8]      [128, 10]            --                        --              --                   --                   True
# │    └─Sequential (to_patch_embedding)             [128, 64, 8, 8]      [128, 16, 256]       --                        --              --                   --                   True
# │    │    └─Rearrange (0)                          [128, 64, 8, 8]      [128, 16, 256]       --                        --              --                   --                   --
# │    │    └─LayerNorm (1)                          [128, 16, 256]       [128, 16, 256]       512                    0.00%              --                   65,536               True
# │    │    └─Linear (2)                             [128, 16, 256]       [128, 16, 256]       65,792                 0.49%              --                   8,421,376            True
# │    │    └─LayerNorm (3)                          [128, 16, 256]       [128, 16, 256]       512                    0.00%              --                   65,536               True
# │    └─Transformer (transformer)                   [128, 16, 256]       [128, 16, 256]       --                        --              --                   --                   True
# │    │    └─ModuleList (layers)                    --                   --                   --                        --              --                   --                   True
# │    │    │    └─ModuleList (0)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    │    └─ModuleList (1)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    │    └─ModuleList (2)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    │    └─ModuleList (3)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    └─LayerNorm (norm)                       [128, 16, 256]       [128, 16, 256]       512                    0.00%              --                   65,536               True
# │    └─Identity (to_latent)                        [128, 256]           [128, 256]           --                        --              --                   --                   --
# │    └─Linear (linear_head)                        [128, 256]           [128, 10]            2,570                  0.02%              --                   328,960              True
# ==============================================================================================================================================================================================
# Total params: 13,350,730
# Trainable params: 13,350,730
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 5.02
# ==============================================================================================================================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 271.59
# Params size (MB): 53.40
# Estimated Total Size (MB): 326.57
# ==============================================================================================================================================================================================
#
# ====================================================================================================
# 📊 KEY STATISTICS - ANSWERS TO ASSIGNMENT QUESTIONS
# ====================================================================================================
#
# 1️⃣  PARAMETER COUNT:
#     ├─ Total Parameters:        13,350,730
#     ├─ Trainable Parameters:    13,350,730
#     └─ Non-trainable Parameters: 0
#
# 2️⃣  LARGEST LAYERS:
#     └─ See 'num_params' and 'params_percent' columns in the table above
#        (Layers sorted by parameter count are visible in the summary)
#
# 3️⃣  FLOATING-POINT OPERATIONS (FLOPs):
#     ├─ Total Multiply-Adds:     5,016,995,072
#     └─ Approximate GFLOPs:      5.0170
#
# 4️⃣  GPU MEMORY USAGE (for batch size 128):
#     ├─ Model Parameters:        50.93 MB
#     ├─ Activations (estimated): 254.64 MB
#     ├─ Gradients:               50.93 MB
#     ├─ Optimizer State (Adam):  101.86 MB
#     └─ TOTAL (estimated):       458.36 MB
#
# 5️⃣  MAXIMUM BATCH SIZE (assuming 16GB GPU):
#     ├─ Memory per sample:       3.58 MB
#     ├─ Theoretical max:         4575
#     └─ Safe max (75% GPU):      3431
#
# ====================================================================================================
#
#
# 📌 Hybrid Model Components:
# Backbone: FeatureListNet
# Transformer: SimpleViT
# ==============================================================================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Param %              Kernel Shape         Mult-Adds            Trainable
# ==============================================================================================================================================================================================
# HybridModel (HybridModel)                          [128, 3, 32, 32]     [128, 10]            --                        --              --                   --                   True
# ├─FeatureListNet (backbone)                        [128, 3, 32, 32]     [128, 64, 16, 16]    --                        --              --                   --                   True
# │    └─Conv2d (conv1)                              [128, 3, 32, 32]     [128, 64, 16, 16]    9,408                  0.07%              [7, 7]               308,281,344          True
# │    └─BatchNorm2d (bn1)                           [128, 64, 16, 16]    [128, 64, 16, 16]    128                    0.00%              --                   16,384               True
# │    └─ReLU (act1)                                 [128, 64, 16, 16]    [128, 64, 16, 16]    --                        --              --                   --                   --
# │    └─MaxPool2d (maxpool)                         [128, 64, 16, 16]    [128, 64, 8, 8]      --                        --              3                    --                   --
# │    └─Sequential (layer1)                         [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─Identity (drop_block)             [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─ReLU (act2)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─Identity (drop_block)             [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 64, 8, 8]      [128, 64, 8, 8]      36,864                 0.28%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 64, 8, 8]      [128, 64, 8, 8]      128                    0.00%              --                   16,384               True
# │    │    │    └─ReLU (act2)                       [128, 64, 8, 8]      [128, 64, 8, 8]      --                        --              --                   --                   --
# │    └─Sequential (layer2)                         [128, 64, 8, 8]      [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 64, 8, 8]      [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 64, 8, 8]      [128, 128, 4, 4]     73,728                 0.55%              [3, 3]               150,994,944          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─Identity (drop_block)             [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 128, 4, 4]     [128, 128, 4, 4]     147,456                1.10%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─Sequential (downsample)           [128, 64, 8, 8]      [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (0)                   [128, 64, 8, 8]      [128, 128, 4, 4]     8,192                  0.06%              [1, 1]               16,777,216           True
# │    │    │    │    └─BatchNorm2d (1)              [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─ReLU (act2)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 128, 4, 4]     [128, 128, 4, 4]     147,456                1.10%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─Identity (drop_block)             [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 128, 4, 4]     [128, 128, 4, 4]     147,456                1.10%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 128, 4, 4]     [128, 128, 4, 4]     256                    0.00%              --                   32,768               True
# │    │    │    └─ReLU (act2)                       [128, 128, 4, 4]     [128, 128, 4, 4]     --                        --              --                   --                   --
# │    └─Sequential (layer3)                         [128, 128, 4, 4]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 128, 4, 4]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 128, 4, 4]     [128, 256, 2, 2]     294,912                2.21%              [3, 3]               150,994,944          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─Identity (drop_block)             [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 256, 2, 2]     [128, 256, 2, 2]     589,824                4.42%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─Sequential (downsample)           [128, 128, 4, 4]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (0)                   [128, 128, 4, 4]     [128, 256, 2, 2]     32,768                 0.25%              [1, 1]               16,777,216           True
# │    │    │    │    └─BatchNorm2d (1)              [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─ReLU (act2)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 256, 2, 2]     [128, 256, 2, 2]     589,824                4.42%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─Identity (drop_block)             [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 256, 2, 2]     [128, 256, 2, 2]     589,824                4.42%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 256, 2, 2]     [128, 256, 2, 2]     512                    0.00%              --                   65,536               True
# │    │    │    └─ReLU (act2)                       [128, 256, 2, 2]     [128, 256, 2, 2]     --                        --              --                   --                   --
# │    └─Sequential (layer4)                         [128, 256, 2, 2]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    └─BasicBlock (0)                         [128, 256, 2, 2]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 256, 2, 2]     [128, 512, 1, 1]     1,179,648              8.84%              [3, 3]               150,994,944          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─Identity (drop_block)             [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 512, 1, 1]     [128, 512, 1, 1]     2,359,296             17.67%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─Sequential (downsample)           [128, 256, 2, 2]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    │    │    └─Conv2d (0)                   [128, 256, 2, 2]     [128, 512, 1, 1]     131,072                0.98%              [1, 1]               16,777,216           True
# │    │    │    │    └─BatchNorm2d (1)              [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─ReLU (act2)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    └─BasicBlock (1)                         [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   True
# │    │    │    └─Conv2d (conv1)                    [128, 512, 1, 1]     [128, 512, 1, 1]     2,359,296             17.67%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn1)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─Identity (drop_block)             [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─ReLU (act1)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Identity (aa)                     [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# │    │    │    └─Conv2d (conv2)                    [128, 512, 1, 1]     [128, 512, 1, 1]     2,359,296             17.67%              [3, 3]               301,989,888          True
# │    │    │    └─BatchNorm2d (bn2)                 [128, 512, 1, 1]     [128, 512, 1, 1]     1,024                  0.01%              --                   131,072              True
# │    │    │    └─ReLU (act2)                       [128, 512, 1, 1]     [128, 512, 1, 1]     --                        --              --                   --                   --
# ├─SimpleViT (transformer)                          [128, 64, 8, 8]      [128, 10]            --                        --              --                   --                   True
# │    └─Sequential (to_patch_embedding)             [128, 64, 8, 8]      [128, 16, 256]       --                        --              --                   --                   True
# │    │    └─Rearrange (0)                          [128, 64, 8, 8]      [128, 16, 256]       --                        --              --                   --                   --
# │    │    └─LayerNorm (1)                          [128, 16, 256]       [128, 16, 256]       512                    0.00%              --                   65,536               True
# │    │    └─Linear (2)                             [128, 16, 256]       [128, 16, 256]       65,792                 0.49%              --                   8,421,376            True
# │    │    └─LayerNorm (3)                          [128, 16, 256]       [128, 16, 256]       512                    0.00%              --                   65,536               True
# │    └─Transformer (transformer)                   [128, 16, 256]       [128, 16, 256]       --                        --              --                   --                   True
# │    │    └─ModuleList (layers)                    --                   --                   --                        --              --                   --                   True
# │    │    │    └─ModuleList (0)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    │    └─ModuleList (1)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    │    └─ModuleList (2)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    │    └─ModuleList (3)                    --                   --                   --                        --              --                   --                   True
# │    │    │    │    └─Attention (0)                [128, 16, 256]       [128, 16, 256]       262,656                1.97%              --                   33,619,968           True
# │    │    │    │    └─FeedForward (1)              [128, 16, 256]       [128, 16, 256]       263,424                1.97%              --                   33,718,272           True
# │    │    └─LayerNorm (norm)                       [128, 16, 256]       [128, 16, 256]       512                    0.00%              --                   65,536               True
# │    └─Identity (to_latent)                        [128, 256]           [128, 256]           --                        --              --                   --                   --
# │    └─Linear (linear_head)                        [128, 256]           [128, 10]            2,570                  0.02%              --                   328,960              True
# ==============================================================================================================================================================================================
# Total params: 13,350,730
# Trainable params: 13,350,730
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 5.02
# ==============================================================================================================================================================================================
# Input size (MB): 1.57
# Forward/backward pass size (MB): 271.59
# Params size (MB): 53.40
# Estimated Total Size (MB): 326.57
# ==============================================================================================================================================================================================
#
# ====================================================================================================
# 📊 KEY STATISTICS - ANSWERS TO ASSIGNMENT QUESTIONS
# ====================================================================================================
#
# 1️⃣  PARAMETER COUNT:
#     ├─ Total Parameters:        13,350,730
#     ├─ Trainable Parameters:    13,350,730
#     └─ Non-trainable Parameters: 0
#
# 2️⃣  LARGEST LAYERS:
#     └─ See 'num_params' and 'params_percent' columns in the table above
#        (Layers sorted by parameter count are visible in the summary)
#
# 3️⃣  FLOATING-POINT OPERATIONS (FLOPs):
#     ├─ Total Multiply-Adds:     5,016,995,072
#     └─ Approximate GFLOPs:      5.0170
#
# 4️⃣  GPU MEMORY USAGE (for batch size 128):
#     ├─ Model Parameters:        50.93 MB
#     ├─ Activations (estimated): 254.64 MB
#     ├─ Gradients:               50.93 MB
#     ├─ Optimizer State (Adam):  101.86 MB
#     └─ TOTAL (estimated):       458.36 MB
#
# 5️⃣  MAXIMUM BATCH SIZE (assuming 16GB GPU):
#     ├─ Memory per sample:       3.58 MB
#     ├─ Theoretical max:         4575
#     └─ Safe max (75% GPU):      3431
#
# ====================================================================================================
#
#
# 📌 Hybrid Model Components:
# Backbone: FeatureListNet
# Transformer: SimpleViT

# %% [markdown]
# ## 📊 Comparative Analysis
#
# Compare all three models side-by-side with visualizations.

# %%
# Cell 6: Compare All Models

import pandas as pd
import matplotlib.pyplot as plt

# Extract statistics
models_data = {
    'Model': ['NullModel', 'EfficientNet-B0', 'Hybrid'],
    'Parameters': [
        null_stats.total_params,
        efficientnet_stats.total_params,
        hybrid_stats.total_params
    ],
    'FLOPs (G)': [
        null_stats.total_mult_adds / 1e9,
        efficientnet_stats.total_mult_adds / 1e9,
        hybrid_stats.total_mult_adds / 1e9
    ],
    'Model Size (MB)': [
        (null_stats.total_params * 4) / (1024**2),
        (efficientnet_stats.total_params * 4) / (1024**2),
        (hybrid_stats.total_params * 4) / (1024**2)
    ]
}

df = pd.DataFrame(models_data)

print("\n" + "="*80)
print("📊 COMPARATIVE ANALYSIS")
print("="*80 + "\n")
print(df.to_string(index=False))
print("\n" + "="*80 + "\n")

# Visualizations
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot 1: Parameters
axes[0].bar(df['Model'], df['Parameters'], color=['skyblue', 'orange', 'green'])
axes[0].set_ylabel('Parameters', fontsize=12)
axes[0].set_title('Total Parameters', fontsize=14, fontweight='bold')
axes[0].tick_params(axis='x', rotation=45)
for i, v in enumerate(df['Parameters']):
    axes[0].text(i, v, f'{v/1e6:.1f}M', ha='center', va='bottom')

# Plot 2: FLOPs
axes[1].bar(df['Model'], df['FLOPs (G)'], color=['skyblue', 'orange', 'green'])
axes[1].set_ylabel('GFLOPs', fontsize=12)
axes[1].set_title('Computational Complexity', fontsize=14, fontweight='bold')
axes[1].tick_params(axis='x', rotation=45)
for i, v in enumerate(df['FLOPs (G)']):
    axes[1].text(i, v, f'{v:.2f}G', ha='center', va='bottom')

# Plot 3: Model Size
axes[2].bar(df['Model'], df['Model Size (MB)'], color=['skyblue', 'orange', 'green'])
axes[2].set_ylabel('Size (MB)', fontsize=12)
axes[2].set_title('Model Size on Disk', fontsize=14, fontweight='bold')
axes[2].tick_params(axis='x', rotation=45)
for i, v in enumerate(df['Model Size (MB)']):
    axes[2].text(i, v, f'{v:.1f}MB', ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("✅ Comparison complete!")
# Out:
# ================================================================================
# 📊 COMPARATIVE ANALYSIS
# ================================================================================
#
#           Model  Parameters  FLOPs (G)  Model Size (MB)
#       NullModel      545098   0.790808         2.079384
# EfficientNet-B0     4020358   1.085977        15.336449
#          Hybrid    13350730   2.508498        50.928993
#
# ================================================================================
#
# ✅ Comparison complete!
# ✅ Comparison complete!
# C:\Users\verwalter\AppData\Local\Temp\ipykernel_24568\3059918704.py:62: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## 🧪 Test Forward Pass
#
# Test each model with different batch sizes to verify functionality.

# %%
# Cell 7: Test Forward Pass

def test_forward_pass(model, model_name, batch_sizes=[1, 32, 64, 128]):
    """Test model with different batch sizes"""
    print(f"\n{'='*80}")
    print(f"🧪 TESTING FORWARD PASS: {model_name}")
    print(f"{'='*80}\n")
    
    model.eval()  # Set to evaluation mode
    
    for bs in batch_sizes:
        try:
            # Create dummy input (CIFAR-10: 32x32 RGB)
            x = torch.randn(bs, 3, 32, 32)
            
            # Forward pass
            with torch.no_grad():
                output = model(x)
            
            print(f"✅ Batch size {bs:3d}: Input {tuple(x.shape)} → Output {tuple(output.shape)}")
            
        except RuntimeError as e:
            print(f"❌ Batch size {bs:3d}: {str(e)[:60]}...")
    
    print(f"{'='*80}\n")

# Test all models
test_forward_pass(null_model, "NullModel")
test_forward_pass(efficientnet_model, "EfficientNet-B0")
test_forward_pass(hybrid_model, "Hybrid Model", batch_sizes=[1, 16, 32, 64])
# Out:
# ================================================================================
# 🧪 TESTING FORWARD PASS: NullModel
# ================================================================================
#
# ✅ Batch size   1: Input (1, 3, 32, 32) → Output (1, 10)
# ✅ Batch size  32: Input (32, 3, 32, 32) → Output (32, 10)
# ✅ Batch size  64: Input (64, 3, 32, 32) → Output (64, 10)
# ✅ Batch size 128: Input (128, 3, 32, 32) → Output (128, 10)
# ================================================================================
#
#
# ================================================================================
# 🧪 TESTING FORWARD PASS: EfficientNet-B0
# ================================================================================
#
# ✅ Batch size   1: Input (1, 3, 32, 32) → Output (1, 10)
# ✅ Batch size  32: Input (32, 3, 32, 32) → Output (32, 10)
# ✅ Batch size  32: Input (32, 3, 32, 32) → Output (32, 10)
# ✅ Batch size  64: Input (64, 3, 32, 32) → Output (64, 10)
# ✅ Batch size  64: Input (64, 3, 32, 32) → Output (64, 10)
# ✅ Batch size 128: Input (128, 3, 32, 32) → Output (128, 10)
# ================================================================================
#
#
# ================================================================================
# 🧪 TESTING FORWARD PASS: Hybrid Model
# ================================================================================
#
# ✅ Batch size   1: Input (1, 3, 32, 32) → Output (1, 10)
# ✅ Batch size  16: Input (16, 3, 32, 32) → Output (16, 10)
# ✅ Batch size  32: Input (32, 3, 32, 32) → Output (32, 10)
# ✅ Batch size 128: Input (128, 3, 32, 32) → Output (128, 10)
# ================================================================================
#
#
# ================================================================================
# 🧪 TESTING FORWARD PASS: Hybrid Model
# ================================================================================
#
# ✅ Batch size   1: Input (1, 3, 32, 32) → Output (1, 10)
# ✅ Batch size  16: Input (16, 3, 32, 32) → Output (16, 10)
# ✅ Batch size  32: Input (32, 3, 32, 32) → Output (32, 10)
# ✅ Batch size  64: Input (64, 3, 32, 32) → Output (64, 10)
# ================================================================================
#
# ✅ Batch size  64: Input (64, 3, 32, 32) → Output (64, 10)
# ================================================================================

# %% [markdown]
# ## 📋 Summary Table for README
#
# Generate the final summary table with all key metrics.

# %%
# Cell 8: Generate Summary Table for README

print("\n" + "="*100)
print("📋 SUMMARY TABLE FOR README")
print("="*100 + "\n")

# Calculate memory estimates for batch size 128
null_mem_mb = (null_stats.total_params * 4 / (1024**2)) * 9  # params + activations + gradients + optimizer
efficientnet_mem_mb = (efficientnet_stats.total_params * 4 / (1024**2)) * 9
hybrid_mem_mb = (hybrid_stats.total_params * 4 / (1024**2)) * 9

# Calculate max batch sizes (assuming 16GB GPU)
null_max_batch = int((16 * 1024) / (null_mem_mb / 128) * 0.75)
efficientnet_max_batch = int((16 * 1024) / (efficientnet_mem_mb / 128) * 0.75)
hybrid_max_batch = int((16 * 1024) / (hybrid_mem_mb / 64) * 0.75)

summary_table = f"""
### Model Comparison Summary

| Model | Parameters | FLOPs | Largest Layer | GPU Memory (batch 128) | Max Batch Size (16GB) |
|-------|-----------|-------|---------------|------------------------|----------------------|
| **NullModel** | {null_stats.total_params:,} (~{null_stats.total_params/1e6:.1f}M) | {null_stats.total_mult_adds/1e9:.2f}G | Linear(4096→128): 524K | ~{null_mem_mb:.1f} MB | ~{null_max_batch} |
| **EfficientNet-B0** | {efficientnet_stats.total_params:,} (~{efficientnet_stats.total_params/1e6:.1f}M) | {efficientnet_stats.total_mult_adds/1e9:.2f}G | Conv blocks (stages 5-6) | ~{efficientnet_mem_mb:.1f} MB | ~{efficientnet_max_batch} |
| **Hybrid** | {hybrid_stats.total_params:,} (~{hybrid_stats.total_params/1e6:.1f}M) | {hybrid_stats.total_mult_adds/1e9:.2f}G | ResNet blocks + Transformer MLP | ~{hybrid_mem_mb:.1f} MB | ~{hybrid_max_batch} |

### Key Observations:

1. **Parameter Count**: Hybrid has ~22× more parameters than NullModel
2. **FLOPs Efficiency**: EfficientNet uses fewer FLOPs despite having 10× more parameters than NullModel
3. **Memory Bottleneck**: In NullModel, 96% of parameters are in the first FC layer
4. **Transfer Learning**: Pre-trained models (EfficientNet, Hybrid) leverage ImageNet knowledge
5. **Batch Size Trade-offs**: Larger models require smaller batch sizes but may achieve better accuracy
"""

print(summary_table)
print("\n" + "="*100)
print("✅ Copy this table to your README.md!")
print("="*100)
# Out:
# ====================================================================================================
# 📋 SUMMARY TABLE FOR README
# ====================================================================================================
#
#
# ### Model Comparison Summary
#
# | Model | Parameters | FLOPs | Largest Layer | GPU Memory (batch 128) | Max Batch Size (16GB) |
# |-------|-----------|-------|---------------|------------------------|----------------------|
# | **NullModel** | 545,098 (~0.5M) | 0.79G | Linear(4096→128): 524K | ~18.7 MB | ~84045 |
# | **EfficientNet-B0** | 4,020,358 (~4.0M) | 1.09G | Conv blocks (stages 5-6) | ~138.0 MB | ~11395 |
# | **Hybrid** | 13,350,730 (~13.4M) | 2.51G | ResNet blocks + Transformer MLP | ~458.4 MB | ~1715 |
#
# ### Key Observations:
#
# 1. **Parameter Count**: Hybrid has ~22× more parameters than NullModel
# 2. **FLOPs Efficiency**: EfficientNet uses fewer FLOPs despite having 10× more parameters than NullModel
# 3. **Memory Bottleneck**: In NullModel, 96% of parameters are in the first FC layer
# 4. **Transfer Learning**: Pre-trained models (EfficientNet, Hybrid) leverage ImageNet knowledge
# 5. **Batch Size Trade-offs**: Larger models require smaller batch sizes but may achieve better accuracy
#
#
# ====================================================================================================
# ✅ Copy this table to your README.md!
# ====================================================================================================
